# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Figure-2.1" data-toc-modified-id="Figure-2.1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Figure 2.1</a></span></li><li><span><a href="#Figure-2.2" data-toc-modified-id="Figure-2.2-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Figure 2.2</a></span></li><li><span><a href="#Figure-2.3" data-toc-modified-id="Figure-2.3-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Figure 2.3</a></span></li></ul></div>

# %%
## Analyzing Neural Time Series Data
# Python code for Chapter 2
# Yujin Goto (MATLAB original code: Mike X Cohen)
# 
# This code accompanies the book, titled "Analyzing Neural Time Series Data" 
# (MIT Press). Using the code without following the book may lead to confusion, 
# incorrect data analyses, and misinterpretations of results. 
# Mike X Cohen and Yujin Goto assumes no responsibility for inappropriate or incorrect use of this code.

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.io import loadmat
from scipy import signal as sig

import mne
from mne import events_from_annotations

# %%
eeg_data = loadmat('./NeuralData/sampleEEGdata.mat')
EEG = eeg_data['EEG'][0, 0]  # Adjust indexing based on the structure of the .mat file

# %%
# load EEG data (.vhdr converted ver. by Yujin)
mne.set_log_level('CRITICAL') # delete this line for your environment
raw = mne.io.read_raw_brainvision('./NeuralData/sampleEEGdata_convert.vhdr', eog=['HEOG', 'VEOG'], preload=True)
mne.set_log_level('INFO') # delete this line for your environment

# load electrodes location montage
montage = mne.channels.read_custom_montage('./NeuralData/sampleEEG_loc.loc')
raw.set_montage(montage)

# Getting event timings (for .mat file, you don't have to do this.) and epoching
events, event_dict = events_from_annotations(raw)

epochs = mne.Epochs(
    raw,
    events,
    event_id = {'New Segment/': 99999},
    tmin = 0,
    tmax = 2.496,
    baseline = None,
)

# Extract variables
data = epochs.get_data()*(10**6)                 # EEG data (array; trial, ch, time). MNE-pyton reads data in volts(V), not microvolts (μV).
pnts = data.shape[2]                             # Number of points in EEG data (scalar)
times = epochs.times-1                           # Time points of data (array)
tmin = epochs.tmin-1                             # The start timing of epoch (the start timing of the baseline is set to be 0 in default)
tmax = epochs.tmax-1                             # The end timing of epoch
srate = epochs.info['sfreq']                     # Sampling rate (scalar)
trials = len(epochs.events)                      # Trials (scalar)
nbchan = len(epochs.ch_names)                    # Number of channel (scalar)


chan_labels = epochs.info['ch_names']

# channel locations
chan_pos = []
for ch in epochs.info['chs']:
    x,y,z = ch['loc'][:3]
    chan_pos.append((x,y,z))
# Out:
# Used Annotations descriptions: ['New Segment/', 'Stimulus/1', 'Stimulus/2', 'Stimulus/31', 'Stimulus/32', 'Stimulus/51', 'Stimulus/52']
# Not setting metadata
# 99 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 99 events and 640 original time points ...
# 0 bad epochs dropped

# %% [markdown]
# ## Figure 2.1

# %%
nTrials = 6

# Initialize the data array
plotdata = np.zeros((nTrials, pnts))

# Wavelet parameters
wavetime = np.arange(-1, 1 + 1/srate, 1/srate)
n_conv = len(wavetime) + pnts - 1
waveletfft = np.fft.fft(np.exp(2 * 1j * np.pi * 10 * wavetime) * np.exp(-wavetime**2 / (2 * (5 / (2*np.pi*10))**2)) / 10, n_conv)
data10hz = np.zeros((nTrials, pnts))

plt.figure(figsize=(15,15))
# Generate and plot data
for triali in range(nTrials):
    
    # Create single trial "ERP"
    plotdata[triali, :] = 0.5 * np.sin(2* np.pi * 6 *times + 2*np.pi*triali/nTrials - np.pi) + np.random.randn(pnts)/6
    # Add non-phase-locked stimulus potential
    idx_range = np.arange(259, 360)  # Adjusted index for Python
    plotdata[triali, idx_range] += np.sin(2*np.pi*10*times[idx_range] + 2*np.pi*triali/nTrials - np.pi) + np.random.randn(len(idx_range))/5
    
    # Plot data from this trial
    plt.subplot(nTrials, 3, triali * 3 + 1)
    plt.plot(times, plotdata[triali, :])
    plt.xlim([-.25, .85])
    plt.xticks(color='None')
    plt.ylim([-2.2, 2.2])
    plt.yticks(color='None')
    legend = f"Trial{triali}"
    plt.text(.65,1.5, legend, fontsize=15)
    if triali == 0:
        plt.title('Single trials', fontsize=15)
    elif triali == nTrials-1:
        plt.xticks(color='black')
        plt.xlabel('Time(ms)', fontsize=15)

    # Plot ERP from trial 1 to current
    plt.subplot(nTrials, 3, triali * 3 + 2)
    plt.plot(times, np.mean(plotdata[:triali+1, :], axis=0))
    plt.xlim([-.25, .85])
    plt.xticks(color='None')
    plt.ylim([-2.2, 2.2])
    plt.yticks(color='None')
    if triali == 0:
        plt.title('ERP from trial 1 to current', fontsize=15)
    elif triali == nTrials-1:
        plt.xticks(color='black')

    # Convolve with 10 Hz wavelet
    convolution_result_fft = np.fft.ifft(waveletfft * np.fft.fft(plotdata[triali, :], n_conv)) * np.sqrt(5/(2*np.pi*10))
    half_of_wavelet_size = int(np.floor(len(wavetime) / 2))
    convolution_result_fft = convolution_result_fft[half_of_wavelet_size:-half_of_wavelet_size]

    data10hz[triali, :] = np.abs(convolution_result_fft)**2

    # Plot 10 Hz power
    plt.subplot(nTrials, 3, triali * 3 + 3)
    plt.plot(times, np.mean(data10hz[:triali+1, :], axis=0))
    plt.xlim([-.25, .85])
    plt.xticks(color='None')
    plt.ylim([-.1, .8])
    plt.yticks(color='None')
    if triali == 0:
        plt.title('Appha power, trial 1 to current', fontsize=15)
    elif triali == nTrials-1:
        plt.xticks(color='black')

plt.show()

# %% [markdown]
# ## Figure 2.2

# %%
#(This code involves performing convolution with a complex Morlet wavelet,
#which you will learn about in Chapters 10-13.)

# %%
# Parameters
s_rate = 1000
time = np.arange(0, 10, 1/s_rate)
DCoffset = -0.5

# Create multi-frequency signal
a = np.sin(2*np.pi*10*time)  # High frequency part
b = 0.1*np.sin(2*np.pi*0.3*time) + DCoffset  # Low frequency part
datas = a * b  # Combined signal
datas += (2*np.sin(2*np.pi*3*time) * np.sin(2*np.pi*0.07*time)*0.1 + DCoffset)

# Morlet wavelet convolution
num_frex = 40
min_freq = 2
max_freq = 20

Ldata = len(datas)
Ltapr = len(datas)
Lconv1 = Ldata + Ltapr -1
Lconv = int(2**np.ceil(np.log2(Lconv1)))
frex = np.logspace(np.log10(min_freq), np.log10(max_freq), num_frex)

# Initialize time-frequency representation
tf = np.zeros((num_frex, len(datas)))
datspctra = fft(datas, Lconv)

s = 4 / (2 * np.pi * frex)
t = np.arange(-Ldata/2, Ldata/2) / s_rate
        
for fi in range(len(frex)):
    wavelet = np.exp(2*1j*np.pi*frex[fi]*t) * np.exp(-t**2 / (2 * s[fi]**2))
    m = ifft(datspctra * fft(wavelet, Lconv), Lconv)
    m = m[:Lconv1]
    m = m[int(np.floor((Ltapr-1)/2)):-int(np.ceil((Ltapr-1)/2))]
    tf[fi, :] = np.abs(m)**2

# %%
# Plotting
plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plt.plot(a)
plt.xlim([1000, 8000])
plt.ylim([-3, 3])
plt.xticks(np.arange(1000, 8001, 1000), np.arange(1, 9))
plt.title('10 Hz signal, DC=0')

plt.subplot(2, 2, 2)
plt.plot(b)
plt.xlim([1000, 8000])
plt.ylim([-1, 1])
plt.xticks(np.arange(1000, 8001, 1000), np.arange(1, 9))
plt.title('0.3 Hz signal, DC={}'.format(DCoffset))

plt.subplot(2, 2, 3)
plt.plot(datas)
plt.xlim([1000, 8000])
plt.ylim([-1, 1])
plt.xticks(np.arange(1000, 8001, 1000), np.arange(1, 9))
plt.title('Time-domain signal')

plt.subplot(2, 2, 4)
plt.imshow(tf, aspect='auto', extent=[len(datas), 0, 0, num_frex], origin='lower')
#plt.colorbar()
plt.xlim([1000, 8000])
plt.yticks(np.arange(1, num_frex+1, 8), np.round(frex[::8]))
plt.xticks(np.arange(1000, 8001, 1000), np.arange(1, 9))
plt.title('Time-frequency representation')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Figure 2.3

# %%
# Select channel
chan2plot = 'Pz' # specify label of channel to plot
channel_index = chan_labels.index(chan2plot) # specify index (channel number) of label

# Compute ERP
erp = np.mean(data[:, channel_index, :], axis=0)

# Low-pass filter parameters
nyquist = int(srate) / 2
filter_cutoff = 40  # Hz
trans_width = 0.1  # Transition width in fraction of 1

# Design filter
ffrequencies = np.array([0, filter_cutoff, filter_cutoff * (1 + trans_width), nyquist]) / nyquist
idealresponse = [1, 1, 0, 0]
filterweights = sig.firls(101, ffrequencies, idealresponse)

# Apply filter
filtered_erp = sig.filtfilt(filterweights, 1, erp)

# Plotting
plt.figure(figsize=(10,8))

# Plot ERP
plt.plot(times, filtered_erp, 'k.-', label='Raw ERP 256 Hz')

# Downsample and plot
downsample_factor = 5
plt.plot(times[0:-1:5], filtered_erp[0:-1:5], 'mo-', label='Downsampled ERP 50 Hz')

plt.xlim([-.2, 1])
plt.xlabel('Time (s)')
plt.ylabel('Voltage (μV)')
plt.title(f'ERP from electrode {chan2plot}', fontsize=15)
plt.legend()
plt.show()
